# %%
import regex

pat = r"'(?i:[sdmt]|ll|ve|re)|[^\r\n\p{L}\p{N}]?+\p{L}+|\p{N}{1,3}| ?[^\s\p{L}\p{N}]++[\r\n]*|\s*[\r\n]|\s+(?!\S)|\s+"
texto = "It's time to code in 2025!"

# Note a flag regex.V1 para comportamento compatível
tokens = regex.findall(pat, texto)
print(tokens)
# Out:
# ['It', "'s", ' time', ' to', ' code', ' in', ' ', '202', '5', '!']

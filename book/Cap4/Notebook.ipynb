# %%
import numpy as np

X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)
X
# Out:
# array([[1.33200279],
#        [1.34386851],
#        [0.26328854],
#        [1.67221353],
#        [1.46826599],
#        [1.98928281],
#        [1.32490461],
#        [0.35760479],
#        [0.85231402],
#        [0.50043642],
#        [1.26866188],
#        [0.57509949],
#        [0.5926722 ],
#        [0.87894124],
#        [1.74454075],
#        [0.63311308],
#        [0.50117214],
#        [1.01086974],
#        [1.81227533],
#        [0.77598321],
#        [0.78086792],
#        [1.17066036],
#        [1.75708344],
#        [0.35940234],
#        [1.33508382],
#        [1.1667752 ],
#        [0.80639116],
#        [1.30394541],
#        [1.41706833],
#        [1.09032892],
#        [0.73787165],
#        [1.97015947],
#        [0.71676346],
#        [1.31261261],
#        [1.18917803],
#        [0.29571811],
#        [1.66450885],
#        [1.54606806],
#        [1.69088824],
#        [0.05229234],
#        [1.26200862],
#        [0.66268616],
#        [1.88605546],
#        [0.92381581],
#        [1.09396553],
#        [0.40167483],
#        [1.993963  ],
#        [0.34746721],
#        [1.89862466],
#        [1.89981712],
#        [0.61043936],
#        [1.87214444],
#        [0.06987735],
#        [1.37828533],
#        [0.1045361 ],
#        [0.87818226],
#        [1.49494999],
#        [1.08840851],
#        [1.63351657],
#        [1.43819158],
#        [1.31590719],
#        [0.09722982],
#        [0.57702296],
#        [0.18084758],
#        [1.9331073 ],
#        [1.81271124],
#        [1.5046865 ],
#        [1.01681672],
#        [0.45194361],
#        [1.99849124],
#        [0.95356319],
#        [1.57959397],
#        [1.6520069 ],
#        [1.40961807],
#        [0.85097715],
#        [0.09209633],
#        [1.56436992],
#        [0.5806429 ],
#        [1.23627619],
#        [1.97466425],
#        [0.28849552],
#        [0.961889  ],
#        [1.68786561],
#        [1.53126825],
#        [0.56987151],
#        [0.66697612],
#        [0.98614381],
#        [1.51387156],
#        [1.9621619 ],
#        [0.99881459],
#        [0.18851381],
#        [1.74853897],
#        [1.67509916],
#        [0.99856435],
#        [1.7959866 ],
#        [0.87923837],
#        [1.83924942],
#        [0.38536899],
#        [0.50397894],
#        [1.78730423]])

# %%
import matplotlib.pyplot as plt

plt.scatter(X, y)

# %%
X_b = np.c_[np.ones((100,1)), X] # add x0 = 1 to each instance
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
theta_best
# Out:
# array([[3.93356825],
#        [2.96604787]])

# %%
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2,1)), X_new]
y_predict = X_new_b.dot(theta_best)
y_predict
# Out:
# array([[3.93356825],
#        [9.86566398]])

# %%
plt.plot(X_new, y_predict, "r-")
plt.plot(X, y, "b.")
plt.axis([0, 2, 0, 15])
plt.show()

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([3.93356825]), array([[2.96604787]]))

# %%
lin_reg.predict(X_new)
# Out:
# array([[3.93356825],
#        [9.86566398]])

# %%
# The same thing, but in numpy
theta_best_svd, residuals, rank, s = np.linalg.lstsq(X_b, y, rcond=1e-6)
theta_best_svd
# Out:
# array([[3.93356825],
#        [2.96604787]])

# %%
np.linalg.pinv(X_b).dot(y)
# Out:
# array([[3.93356825],
#        [2.96604787]])

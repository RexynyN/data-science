# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import cv2
import sys
np.set_printoptions(threshold=sys.maxsize)

# %%
img = cv2.imread("binguinho.jpeg")
img.shape
# Out:
# (136, 109, 3)

# %%
plt.imshow(img)

# %%
import base64
import io
from PIL import Image
base65  = """
...
"""

decoded = base64.b64decode(base65)
img = Image.open(io.BytesIO(decoded))
plt.imshow(img);
